# %%
# import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt
# from dateutil.parser import parse

# %%
archivo = "../data/Temixco_TMY.csv"
tmy = pd.read_csv(archivo,index_col=0,parse_dates=True)

# %%
tmy.plot(figsize=(20,20),subplots=True,use_index=False)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>], dtype=object)
